# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=1448401925140028#setting/sparkui/0418-202307-npjfgy03/driver-3395206212321619208">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>spark://10.139.64.4:7077</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
from pyspark.sql import *

# %%
schema = "email string, avatar string, \
                     avg_session_length double, \
                     time_on_app  double, \
                     time_on_website double, \
                     length_of_membership double, \
                     yearly_amount_spent double"

# %%
df = spark.read.csv(schema = schema, \
                    header = True, \
                    path = "/FileStore/tables/ecommerce/ecommerce.csv")

# %%
df.count()
# Out:
# Out[10]: 500

# %%
df.describe().show()
# Out:
# +-------+-----------------+-----------+------------------+------------------+------------------+--------------------+-------------------+
# |summary|            email|     avatar|avg_session_length|       time_on_app|   time_on_website|length_of_membership|yearly_amount_spent|
# +-------+-----------------+-----------+------------------+------------------+------------------+--------------------+-------------------+
# |  count|              500|        500|               500|               500|               500|                 500|                500|
# |   mean|             null|       null|    33.05319351824|12.052487936928012|37.060445421080004|  3.5334615559298004|  499.3140382608002|
# | stddev|             null|       null|0.9925631111602911|0.9942156084624618|1.0104889068105993|  0.9992775024372845|  79.31478155115914|
# |    min|aaron04@yahoo.com|  AliceBlue|       29.53242897|       8.508152176|       33.91384725|          0.26990109|        256.6705823|
# |    max|zscott@wright.com|YellowGreen|       36.13966249|       15.12699429|       40.00518164|         6.922689335|        765.5184619|
# +-------+-----------------+-----------+------------------+------------------+------------------+--------------------+-------------------+

# %%
stringIndexerCol = ["email", "avatar"]

# %%
from pyspark.ml.feature import StringIndexer
email_indexer = StringIndexer(inputCol="email", outputCol="emailIndex")
df1 = email_indexer.fit(df).transform(df)

avatar_index = StringIndexer(inputCol="avatar", outputCol="avatarIndex")
df2 = avatar_index.fit(df1).transform(df1)

df2.show()
# Out:
# +--------------------+----------------+------------------+-----------+---------------+--------------------+-------------------+----------+-----------+
# |               email|          avatar|avg_session_length|time_on_app|time_on_website|length_of_membership|yearly_amount_spent|emailIndex|avatarIndex|
# +--------------------+----------------+------------------+-----------+---------------+--------------------+-------------------+----------+-----------+
# |mstephenson@ferna...|          Violet|       34.49726773|12.65565115|    39.57766802|         4.082620633|         587.951054|     342.0|       96.0|
# |   hduke@hotmail.com|       DarkGreen|       31.92627203|11.10946073|    37.26895887|         2.664034182|        392.2049334|     190.0|       26.0|
# |    pallen@yahoo.com|          Bisque|       33.00091476|11.33027806|    37.11059744|         4.104543202|        487.5475049|     355.0|        6.0|
# |riverarebecca@gma...|     SaddleBrown|       34.30555663|13.71751367|    36.72128268|         3.120178783|         581.852344|     391.0|       18.0|
# |mstephens@davidso...|MediumAquaMarine|       33.33067252|12.79518855|     37.5366533|         4.446308318|         599.406092|     341.0|       87.0|
# |alvareznancy@luca...|     FloralWhite|       33.87103788|12.02692534|    34.47687763|         5.493507201|        637.1024479|      17.0|       49.0|
# |katherine20@yahoo...|   DarkSlateBlue|        32.0215955|11.36634831|    36.68377615|         4.685017247|        521.5721748|     259.0|       80.0|
# |  awatkins@yahoo.com|            Aqua|       32.73914294|12.35195897|    37.37335886|         4.434273435|        549.9041461|      43.0|        5.0|
# |vchurch@walter-ma...|          Salmon|        33.9877729|13.38623528|    37.53449734|         3.273433578|         570.200409|     460.0|       92.0|
# |    bonnie69@lin.biz|           Brown|       31.93654862|11.81412829|    37.14516822|         3.202806072|        427.1993849|      56.0|       24.0|
# |andrew06@peterson...|          Tomato|       33.99257277|13.33897545|    37.22580613|         2.482607771|        492.6060127|      23.0|       19.0|
# |ryanwerner@freema...|          Tomato|       33.87936082|  11.584783|    37.08792607|         3.713209203|        522.3374046|     404.0|       19.0|
# |   knelson@gmail.com|       RoyalBlue|       29.53242897| 10.9612984|    37.42021558|         4.046423164|        408.6403511|     276.0|       67.0|
# |wrightpeter@yahoo...|          Bisque|       33.19033404|12.95922609|     36.1446667|         3.918541839|        573.4158673|     491.0|        6.0|
# |taylormason@gmail...|        DarkBlue|       32.38797585|13.14872569|    36.61995708|         2.494543647|        470.4527333|     439.0|       75.0|
# | jstark@anderson.com|            Peru|       30.73772037|12.63660605|    36.21376309|         3.357846842|        461.7807422|     252.0|      118.0|
# | wjennings@gmail.com|      PowderBlue|        32.1253869|11.73386169|    34.89409275|         3.136132716|        457.8476959|     489.0|      135.0|
# |rebecca45@hale-ba...|       OliveDrab|       32.33889932|12.01319469|    38.38513659|         2.420806161|        407.7045475|     383.0|       14.0|
# |alejandro75@hotma...|            Cyan|       32.18781205|14.71538754|    38.24411459|         1.516575581|        452.3156755|      10.0|        1.0|
# |samuel46@love-wes...|   LightSeaGreen|       32.61785606|13.98959256|     37.1905038|          4.06454855|        605.0610388|     407.0|       59.0|
# +--------------------+----------------+------------------+-----------+---------------+--------------------+-------------------+----------+-----------+
# only showing top 20 rows

# %%
df2.show(2, truncate=True)
# Out:
# +--------------------+---------+------------------+-----------+---------------+--------------------+-------------------+----------+-----------+
# |               email|   avatar|avg_session_length|time_on_app|time_on_website|length_of_membership|yearly_amount_spent|emailIndex|avatarIndex|
# +--------------------+---------+------------------+-----------+---------------+--------------------+-------------------+----------+-----------+
# |mstephenson@ferna...|   Violet|       34.49726773|12.65565115|    39.57766802|         4.082620633|         587.951054|     342.0|       96.0|
# |   hduke@hotmail.com|DarkGreen|       31.92627203|11.10946073|    37.26895887|         2.664034182|        392.2049334|     190.0|       26.0|
# +--------------------+---------+------------------+-----------+---------------+--------------------+-------------------+----------+-----------+
# only showing top 2 rows

# %%
split_df = df2.randomSplit([0.7, 0.3])
# Out:
# 347
# 153

# %%
train_df = split_df[0]
test_df = split_df[1]

print(f"Training rows: {train_df.count()} and Testing rows: {test_df.count()}")
# Out:
# Training rows: 347 and Testing rows: 153

# %%
from pyspark.ml.feature import *
from pyspark.sql.functions import *

assembler = VectorAssembler(inputCols = ["emailIndex", "avatarIndex", "avg_session_length", "time_on_app", "time_on_website", "length_of_membership"], outputCol = "features")
training_df = assembler.transform(train_df)
training_df = training_df.select("features", col("yearly_amount_spent").alias("label"))
training_df.show()
# Out:
# +--------------------+-----------+
# |            features|      label|
# +--------------------+-----------+
# |[0.0,68.0,33.7051...|521.2407802|
# |[1.0,12.0,32.4495...|503.9783791|
# |[2.0,101.0,33.452...|576.4776072|
# |[6.0,17.0,32.8487...|404.8245289|
# |[7.0,65.0,32.6027...|482.1449969|
# |[8.0,133.0,32.291...|494.5518611|
# |[9.0,99.0,33.5030...|419.9387748|
# |[11.0,71.0,32.693...|501.9282649|
# |[12.0,36.0,32.836...|256.6705823|
# |[14.0,48.0,32.887...| 684.163431|
# |[15.0,105.0,33.63...|  497.81193|
# |[17.0,49.0,33.871...|637.1024479|
# |[18.0,24.0,34.188...| 583.977802|
# |[19.0,48.0,32.063...|378.3309069|
# |[20.0,0.0,32.0961...|375.3984554|
# |[22.0,76.0,32.959...| 448.340425|
# |[23.0,19.0,33.992...|492.6060127|
# |[24.0,44.0,34.501...| 584.105885|
# |[25.0,89.0,32.657...|516.8315567|
# |[26.0,53.0,32.133...|443.4418601|
# +--------------------+-----------+
# only showing top 20 rows

# %%
from pyspark.ml.regression import *

lr = LinearRegression(featuresCol = "features", labelCol = "label", maxIter = 10, regParam = 0.3)
model = lr.fit(training_df)

print(model)
# Out:
# LinearRegressionModel: uid=LinearRegression_35d27579c3c6, numFeatures=6

# %%
model.summary.tValues
# Out:
# Out[67]: [0.6880965531459844,
#  0.862715903741891,
#  46.64447395044461,
#  69.46781860660127,
#  1.4463291907903089,
#  112.6218629242398,
#  -38.21732693028442]

# %%
testing_df = assembler.transform(test_df)
testing_df = testing_df.select("features", col("yearly_amount_spent").alias("true_label"))
testing_df.show()
# Out:
# +--------------------+-----------+
# |            features| true_label|
# +--------------------+-----------+
# |[3.0,18.0,31.4474...|418.6027421|
# |[4.0,21.0,32.4256...|420.7376732|
# |[5.0,69.0,33.5477...|476.1914133|
# |[10.0,1.0,32.1878...|452.3156755|
# |[13.0,0.0,31.9673...|445.7498412|
# |[16.0,72.0,31.954...|439.9978799|
# |[21.0,2.0,33.9252...| 483.673308|
# |[27.0,58.0,34.606...|402.1671222|
# |[30.0,34.0,33.700...|492.5568337|
# |[31.0,26.0,32.351...|532.9352188|
# |[37.0,10.0,31.673...|475.7250679|
# |[39.0,7.0,34.3307...|558.4272572|
# |[41.0,22.0,33.811...|535.3216101|
# |[42.0,115.0,32.04...|497.3895578|
# |[46.0,100.0,33.35...|549.0082269|
# |[50.0,25.0,33.471...|515.8288149|
# |[56.0,24.0,31.936...|427.1993849|
# |[62.0,63.0,33.900...|442.6672517|
# |[63.0,28.0,34.695...|510.4013885|
# |[65.0,27.0,32.175...|588.7126055|
# +--------------------+-----------+
# only showing top 20 rows

# %%
prediction = model.transform(testing_df)

# %%
prediction.show()
# Out:
# +--------------------+-----------+------------------+
# |            features| true_label|        prediction|
# +--------------------+-----------+------------------+
# |[3.0,18.0,31.4474...|418.6027421| 424.6516713734743|
# |[4.0,21.0,32.4256...|420.7376732| 401.3139222580028|
# |[5.0,69.0,33.5477...|476.1914133|480.97626022798204|
# |[10.0,1.0,32.1878...|452.3156755|457.32446522006694|
# |[13.0,0.0,31.9673...|445.7498412| 449.5065740875873|
# |[16.0,72.0,31.954...|439.9978799|431.23061812563196|
# |[21.0,2.0,33.9252...| 483.673308| 492.6302668467058|
# |[27.0,58.0,34.606...|402.1671222|424.11410711909457|
# |[30.0,34.0,33.700...|492.5568337|  500.209598389077|
# |[31.0,26.0,32.351...|532.9352188| 526.7961241912469|
# |[37.0,10.0,31.673...|475.7250679|500.85814749702695|
# |[39.0,7.0,34.3307...|558.4272572| 557.2574712595822|
# |[41.0,22.0,33.811...|535.3216101| 530.7181993688987|
# |[42.0,115.0,32.04...|497.3895578| 480.7376487669892|
# |[46.0,100.0,33.35...|549.0082269| 549.9360657079917|
# |[50.0,25.0,33.471...|515.8288149| 521.7030844465544|
# |[56.0,24.0,31.936...|427.1993849| 440.2993036252949|
# |[62.0,63.0,33.900...|442.6672517|443.05231149179826|
# |[63.0,28.0,34.695...|510.4013885|501.74674942954175|
# |[65.0,27.0,32.175...|588.7126055| 576.2520768108534|
# +--------------------+-----------+------------------+
# only showing top 20 rows

# %%
prediction.createOrReplaceTempView("ecommerce_prediction")

# %%
# %sql
select prediction, true_label from ecommerce_prediction;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>prediction</th><th>true_label</th></tr></thead><tbody><tr><td>424.6516713734743</td><td>418.6027421</td></tr><tr><td>401.3139222580028</td><td>420.7376732</td></tr><tr><td>480.97626022798204</td><td>476.1914133</td></tr><tr><td>457.32446522006694</td><td>452.3156755</td></tr><tr><td>449.5065740875873</td><td>445.7498412</td></tr><tr><td>431.23061812563196</td><td>439.9978799</td></tr><tr><td>492.6302668467058</td><td>483.673308</td></tr><tr><td>424.11410711909457</td><td>402.1671222</td></tr><tr><td>500.209598389077</td><td>492.5568337</td></tr><tr><td>526.7961241912469</td><td>532.9352188</td></tr><tr><td>500.85814749702695</td><td>475.7250679</td></tr><tr><td>557.2574712595822</td><td>558.4272572</td></tr><tr><td>530.7181993688987</td><td>535.3216101</td></tr><tr><td>480.7376487669892</td><td>497.3895578</td></tr><tr><td>549.9360657079917</td><td>549.0082269</td></tr><tr><td>521.7030844465544</td><td>515.8288149</td></tr><tr><td>440.2993036252949</td><td>427.1993849</td></tr><tr><td>443.05231149179826</td><td>442.6672517</td></tr><tr><td>501.74674942954175</td><td>510.4013885</td></tr><tr><td>576.2520768108534</td><td>588.7126055</td></tr><tr><td>497.7218224261626</td><td>491.9115051</td></tr><tr><td>507.9207968521607</td><td>511.97986</td></tr><tr><td>501.4226521862206</td><td>512.8253581</td></tr><tr><td>433.1136450892286</td><td>451.6286105</td></tr><tr><td>571.2481973433134</td><td>554.7220838</td></tr><tr><td>538.1608333707188</td><td>532.7174857</td></tr><tr><td>671.1410423677937</td><td>666.1255917</td></tr><tr><td>553.1832011673748</td><td>547.7099886</td></tr><tr><td>375.52202949015395</td><td>384.3260571</td></tr><tr><td>477.96179553239654</td><td>478.1703341</td></tr><tr><td>445.3790616039946</td><td>456.4695101</td></tr><tr><td>456.1084428452257</td><td>461.1122484</td></tr><tr><td>460.2234625504566</td><td>463.4849954</td></tr><tr><td>447.18955385157915</td><td>451.5756852</td></tr><tr><td>517.4195352562992</td><td>529.2300901</td></tr><tr><td>283.9534353286733</td><td>302.1895478</td></tr><tr><td>614.9717470621981</td><td>604.8413188</td></tr><tr><td>468.84018582228987</td><td>475.2634237</td></tr><tr><td>468.3595949028795</td><td>468.4457372</td></tr><tr><td>472.65166799438316</td><td>479.7319491</td></tr><tr><td>586.9439123496768</td><td>593.1564015</td></tr><tr><td>389.41741398586896</td><td>387.5347163</td></tr><tr><td>647.4786973875873</td><td>663.8036933</td></tr><tr><td>408.2512071589697</td><td>408.6201878</td></tr><tr><td>350.06289585681</td><td>347.7769266</td></tr><tr><td>468.3286351446093</td><td>473.7289665</td></tr><tr><td>624.2572221830671</td><td>614.7153338</td></tr><tr><td>497.84373309578837</td><td>488.7860611</td></tr><tr><td>598.474781796552</td><td>604.3348401</td></tr><tr><td>408.0068603983693</td><td>412.0129313</td></tr><tr><td>442.8587168592219</td><td>424.7626355</td></tr><tr><td>490.7785744842786</td><td>501.2091727</td></tr><tr><td>601.6230415168548</td><td>593.915003</td></tr><tr><td>525.9423399590182</td><td>520.8987945</td></tr><tr><td>640.698090312668</td><td>642.1015787</td></tr><tr><td>399.45174282945027</td><td>393.857371</td></tr><tr><td>482.67864967831724</td><td>490.6004425</td></tr><tr><td>380.1849208543199</td><td>392.2049334</td></tr><tr><td>525.1451736174402</td><td>523.6339351</td></tr><tr><td>545.1911648776754</td><td>538.7749335</td></tr><tr><td>425.0941170904159</td><td>425.745092</td></tr><tr><td>488.80138150783114</td><td>495.2994425</td></tr><tr><td>562.5955874848053</td><td>554.900783</td></tr><tr><td>418.4086620368778</td><td>409.0945262</td></tr><tr><td>459.33307187658215</td><td>467.4278485</td></tr><tr><td>458.7335143162056</td><td>447.6879065</td></tr><tr><td>550.7913118936306</td><td>567.4750105</td></tr><tr><td>504.20706658086715</td><td>489.9080531</td></tr><tr><td>459.2943740453252</td><td>453.1695024</td></tr><tr><td>657.8120565137542 ...
# Output can only be rendered in Databricks

# %%
from pyspark.ml.evaluation import *

evaluator = RegressionEvaluator(predictionCol = 'prediction', \
                            labelCol = 'true_label', \
                            metricName = 'rmse')

rmse = evaluator.evaluate(prediction)
print(f"Root Mean Square Error: {rmse}")
# Out:
# Root Mean Square Error: 9.910798714615945
